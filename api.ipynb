# %%
import requests
import pandas as pd
import logging
from dotenv import load_dotenv
import os

# Load environment variables
load_dotenv()
fetch_data_url = os.getenv('FETCH_DATA_URL')

# Configure logging
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s'
)
logger = logging.getLogger(__name__)

class DataFetcher:
    @staticmethod
    def get_all_books():
        try:
            response = requests.get(f'{fetch_data_url}/book/all-books')
            response.raise_for_status()
            raw_data = response.json()
            logger.debug("Raw books data: %s", raw_data)
            data = pd.DataFrame(raw_data['books'])  # Extract 'books' key
            logger.info("Fetched books data: %s rows, columns: %s", data.shape[0], list(data.columns))
            logger.debug("Books data sample:\n%s", data.head().to_string())
            return data
        except requests.RequestException as e:
            logger.error("Failed to fetch books: %s", str(e))
            raise Exception(f"Failed to fetch books: {str(e)}")
        except (KeyError, TypeError) as e:
            logger.error("Invalid books data format: %s", str(e))
            raise Exception(f"Invalid books data format: {str(e)}")

    @staticmethod
    def get_all_users():
        try:
            response = requests.get(f'{fetch_data_url}/user/all-users')
            response.raise_for_status()
            raw_data = response.json()
            logger.debug("Raw users data: %s", raw_data)
            data = pd.DataFrame(raw_data['users'])  # Extract 'users' key
            if not all(col in data.columns for col in ['id', 'gender']):
                logger.error("Invalid users data: missing 'id' or 'gender'. Available columns: %s", list(data.columns))
                raise ValueError("Users data must contain 'id' and 'gender'")
            data = data[['id', 'gender']]
            logger.info("Fetched users data: %s rows, columns: %s", data.shape[0], list(data.columns))
            logger.debug("Users data sample:\n%s", data.head().to_string())
            return data
        except requests.RequestException as e:
            logger.error("Failed to fetch users: %s", str(e))
            raise Exception(f"Failed to fetch users: {str(e)}")
        except (KeyError, ValueError) as e:
            logger.error("Data validation error: %s", str(e))
            raise Exception(f"Data validation error: {str(e)}")

    @staticmethod
    def get_book_genres():
        try:
            response = requests.get(f'{fetch_data_url}/book/all-book-genres')
            response.raise_for_status()
            raw_data = response.json()
            logger.debug("Raw book genres data: %s", raw_data)
            data = pd.DataFrame(raw_data['book_genres'])  # Extract 'book_genres' key
            if not all(col in data.columns for col in ['book_id', 'genre_id']):
                logger.error("Invalid book genres data: missing 'book_id' or 'genre_id'. Available columns: %s", list(data.columns))
                raise ValueError("Book genres data must contain 'book_id' and 'genre_id'")
            logger.info("Fetched book genres data: %s rows, unique books: %s, unique genres: %s", 
                        data.shape[0], data['book_id'].nunique(), data['genre_id'].nunique())
            logger.debug("Book genres data sample:\n%s", data.head().to_string())
            return data
        except requests.RequestException as e:
            logger.error("Failed to fetch book genres: %s", str(e))
            raise Exception(f"Failed to fetch book genres: {str(e)}")
        except (KeyError, ValueError) as e:
            logger.error("Data validation error: %s", str(e))
            raise Exception(f"Data validation error: {str(e)}")

    @staticmethod
    def get_user_preferred_genres():
        try:
            response = requests.get(f'{fetch_data_url}/user/user-preferences')
            response.raise_for_status()
            raw_data = response.json()
            logger.debug("Raw user preferences data: %s", raw_data)
            data = pd.DataFrame(raw_data['user_preferred_genres'])  # Extract 'user_preferred_genres' key
            if not all(col in data.columns for col in ['user_id', 'genre_id']):
                logger.error("Invalid user preferences data: missing 'user_id' or 'genre_id'. Available columns: %s", list(data.columns))
                raise ValueError("User preferences data must contain 'user_id' and 'genre_id'")
            logger.info("Fetched user preferred genres data: %s rows, columns: %s", data.shape[0], list(data.columns))
            logger.debug("User preferred genres data sample:\n%s", data.head().to_string())
            return data
        except requests.RequestException as e:
            logger.error("Failed to fetch user preferred genres: %s", str(e))
            raise Exception(f"Failed to fetch user preferred genres: {str(e)}")
        except (KeyError, ValueError) as e:
            logger.error("Data validation error: %s", str(e))
            raise Exception(f"Data validation error: {str(e)}")

    @staticmethod
    def get_user_item_matrix():
        try:
            response = requests.get(f'{fetch_data_url}/user/user-review')
            response.raise_for_status()
            raw_data = response.json()
            logger.debug("Raw user reviews data: %s", raw_data['reviews'][:5])
            reviews_df = pd.DataFrame(raw_data['reviews'])  # Extract 'reviews' key
            user_item_matrix = reviews_df.pivot(index='user_id', columns='book_id', values='rating').fillna(0)
            logger.info("Fetched user-item matrix: %s users, %s books", user_item_matrix.shape[0], user_item_matrix.shape[1])
            logger.debug("User-item matrix sample:\n%s", user_item_matrix.head().to_string())
            return user_item_matrix
        except requests.RequestException as e:
            logger.error("Failed to fetch user-item matrix: %s", str(e))
            raise Exception(f"Failed to fetch user-item matrix: {str(e)}")
        except (KeyError, TypeError) as e:
            logger.error("Invalid user-item matrix data format: %s", str(e))
            raise Exception(f"Invalid user-item matrix data format: {str(e)}")

# %%
fetcher = DataFetcher()

# %%
fetcher.get_all_books()
# Out:
# 2025-03-14 21:03:25,995 - INFO - Fetched books data: 20 rows, columns: ['id', 'title', 'author', 'description', 'language', 'isbn', 'publisher', 'publish_date', 'cover_image_url', 'num_ratings', 'average_rating', 'created_at', 'updated_at']
#     id                                              title  \
# 0    1                                   The Hunger Games
# 1    2          Harry Potter and the Order of the Phoenix
# 2    3                              To Kill a Mockingbird
# 3    5                                           Twilight
# 4    6                                     The Book Thief
# 5    7                                        Animal Farm
# 6    9  J.R.R. Tolkien 4-Book Boxed Set: The Hobbit an...
# 7   10                                 Gone with the Wind
# 8   13                                    The Giving Tree
# 9   14                                  Wuthering Heights
# 10  16                                Memoirs of a Geisha
# 11  18  Alice's Adventures in Wonderland & Through the...
# 12  19                                          Jane Eyre
# 13  21                                     Fahrenheit 451
# 14  22                                          Divergent
# 15  23                                  Lord of the Flies
# 16  24                                   Romeo and Juliet
# 17  25                                      The Alchemist
# 18  26                               Crime and Punishment
# 19  29                                      City of Bones
#
#                                                author  \
# 0                                     Suzanne Collins
# 1           J.K. Rowling, Mary GrandPré (Illustrator)
# 2                                          Harper Lee
# 3                                     Stephenie Meyer
# 4                     Markus Zusak (Goodreads Author)
# 5   George Orwell, Russell Baker (Preface), C.M. W...
# 6                                      J.R.R. Tolkien
# 7                                   Margaret Mitchell
# 8                                    Shel Silverstein
# 9   Emily Brontë, Richard J. Dunn (Editor), David ...
# 10                                      Arthur Golden
# 11  Lewis Carroll, John Tenniel (Illustrator), Mar...
# 12  Charlotte Brontë, Michael Mason (Editor), Barn...
# 13                                       Ray Bradbury
# 14                   Veronica Roth (Goodreads Author)
# 15                                    William Golding
# 16  William Shakespeare, Paul Werstine (Editor), B...
# 17  Paulo Coelho (Goodreads Author), Alan R. Clark...
# 18      Fyodor Dostoyevsky, David McDuff (Translator)
# 19                 Cassandra Clare (Goodreads Author)
#
#                                           description language           isbn  \
# 0   WINNING MEANS FAME AND FORTUNE.LOSING MEANS CE...  English  9780439023481
# 1   There is a door at the end of a silent corrido...  English  9780439358071
# 2   The unforgettable novel of a childhood in a sl...  English  9999999999999
# 3   About three things I was absolutely positive.\...  English  9780316015844
# 4   Librarian's note: An alternate cover edition c...  English  9780375831003
# 5   Librarian's note: There is an Alternate Cover ...  English  9780451526342
# 6   This four-volume, boxed set contains J.R.R. To...  English  9780345538376
# 7   Scarlett O'Hara, the beautiful, spoiled daught...  English  9780446675536
# 8   "Once there was a tree...and she loved a littl...  English  9780060256654
# 9   You can find the redesigned cover of this edit...  English  9780393978896
# 10  A literary sensation and runaway bestseller, t...  English  9781400096893
# 11  "I can't explain myself, I'm afraid, sir," sai...  English  9780451527745
# 12  Orphaned as a child, Jane has felt an outcast ...  English  9780142437209
# 13  Guy Montag is a fireman. In his world, where t...  English     B0064CPN7I
# 14  In Beatrice Prior's dystopian Chicago world, s...  English  9780062024039
# 15  At the dawn of the next world war, a plane cra...  English  9780140283334
# 16  In Romeo and Juliet, Shakespeare creates a vio...  English  9780743477116
# 17  Paulo Coelho's enchanting novel has inspired a...  English  9780062315007
# 18  Raskolnikov, a destitute and desperate former ...  English  9780143058144
# 19  When fifteen-year-old Clary Fray heads out to ...  English  9781416914280
#
#                            publisher          publish_date  \
# 0                   Scholastic Press  2008-09-14T00:00:00Z
# 1                    Scholastic Inc.  2004-09-28T00:00:00Z
# 2   Harper Perennial Modern Classics  2006-05-23T00:00:00Z
# 3          Little, Brown and Company  2006-09-06T00:00:00Z
# 4                    Alfred A. Knopf  2006-03-14T00:00:00Z
# 5                    Signet Classics  1996-04-28T00:00:00Z
# 6                   Ballantine Books  2012-09-25T00:00:00Z
# 7                       Warner Books  1999-04-01T00:00:00Z
# 8           HarperCollins Publishers  2064-10-07T00:00:00Z
# 9                             Norton  2002-10-28T00:00:00Z
# 10                 Vintage Books USA  2005-11-22T00:00:00Z
# 11               Penguin Group (USA)  2000-12-01T00:00:00Z
# 12                           Penguin  2003-02-04T00:00:00Z
# 13                  Simon & Schuster  2011-11-29T00:00:00Z
# 14             Katherine Tegen Books  2012-02-28T00:00:00Z
# 15                     Penguin Books  1999-10-01T00:00:00Z
# 16                    Simon Schuster  2004-01-01T00:00:00Z
# 17                         HarperOne  2014-04-15T00:00:00Z
# 18                           Penguin  2002-12-31T00:00:00Z
# 19       Margaret K. McElderry Books  2007-03-27T00:00:00Z
#
#                                       cover_image_url num_ratings  \
# 0   https://i.gr-assets.com/images/S/compressed.ph...           0
# 1   https://i.gr-assets.com/images/S/compressed.ph...           1
# 2   https://i.gr-assets.com/images/S/compressed.ph...           0
# 3   https://i.gr-assets.com/images/S/compressed.ph...           0
# 4   https://i.gr-assets.com/images/S/compressed.ph...           0
# 5   https://i.gr-assets.com/images/S/compressed.ph...           0
# 6   https://i.gr-assets.com/images/S/compressed.ph...           0
# 7   https://i.gr-assets.com/images/S/compressed.ph...           0
# 8   https://i.gr-assets.com/images/S/compressed.ph...           0
# 9   https://i.gr-assets.com/images/S/compressed.ph...           0
# 10  https://i.gr-assets.com/images/S/compressed.ph...           0
# 11  https://i.gr-assets.com/images/S/compressed.ph...           0
# 12  https://i.gr-assets.com/images/S/compressed.ph...           0
# 13  https://i.gr-assets.com/images/S/compressed.ph...           0
# 14  https://i.gr-assets.com/images/S/compressed.ph...           0
# 15  https://i.gr-assets.com/images/S/compressed.ph...           0
# 16  https://i.gr-assets.com/images/S/compressed.ph...           1
# 17  https://i.gr-assets.com/images/S/compressed.ph...           0
# 18  https://i.gr-assets.com/images/S/compressed.ph...           0
# 19  https://i.gr-assets.com/images/S/compressed.ph...           0
#
#    average_rating            created_at            updated_at
# 0            0.00  0001-01-01T00:00:00Z  0001-01-01T00:00:00Z
# 1            4.00  0001-01-01T00:00:00Z  0001-01-01T00:00:00Z
# 2            0.00  0001-01-01T00:00:00Z  0001-01-01T00:00:00Z
# 3            0.00  0001-01-01T00:00:00Z  0001-01-01T00:00:00Z
# 4            0.00  0001-01-01T00:00:00Z  0001-01-01T00:00:00Z
# 5            0.00  0001-01-01T00:00:00Z  0001-01-01T00:00:00Z
# 6            0.00  0001-01-01T00:00:00Z  0001-01-01T00:00:00Z
# 7            0.00  0001-01-01T00:00:00Z  0001-01-01T00:00:00Z
# 8            0.00  0001-01-01T00:00:00Z  0001-01-01T00:00:00Z
# 9            0.00  0001-01-01T00:00:00Z  0001-01-01T00:00:00Z
# 10           0.00  0001-01-01T00:00:00Z  0001-01-01T00:00:00Z
# 11           0.00  0001-01-01T00:00:00Z  0001-01-01T00:00:00Z
# 12           0.00  0001-01-01T00:00:00Z  0001-01-01T00:00:00Z
# 13           0.00  0001-01-01T00:00:00Z  0001-01-01T00:00:00Z
# 14           0.00  0001-01-01T00:00:00Z  0001-01-01T00:00:00Z
# 15           0.00  0001-01-01T00:00:00Z  0001-01-01T00:00:00Z
# 16           5.00  0001-01-01T00:00:00Z  0001-01-01T00:00:00Z
# 17           0.00  0001-01-01T00:00:00Z  0001-01-01T00:00:00Z
# 18           0.00  0001-01-01T00:00:00Z  0001-01-01T00:00:00Z
# 19           0.00  0001-01-01T00:00:00Z  0001-01-01T00:00:00Z

# %%
fetcher.get_all_users()
# Out:
# 2025-03-14 21:03:26,073 - INFO - Fetched users data: 2 rows, columns: ['id', 'gender']
#    id  gender
# 0   1  female
# 1   2   other

# %%
fetcher.get_book_genres()
# Out:
# 2025-03-14 21:03:26,171 - INFO - Fetched book genres data: 200 rows, unique books: 20, unique genres: 60
#      book_id  genre_id
# 0          1         1
# 1          1         2
# 2          1         3
# 3          1         4
# 4          1         5
# ..       ...       ...
# 195       29         2
# 196       29        24
# 197       29        27
# 198       29        60
# 199       29        11
#
# [200 rows x 2 columns]

# %%
fetcher.get_user_preferred_genres()
# Out:
# 2025-03-14 21:03:26,252 - INFO - Fetched user preferred genres data: 4 rows, columns: ['user_id', 'genre_id']
#    user_id  genre_id
# 0        1         4
# 1        1        23
# 2        1        30
# 3        1        41

# %%
fetcher.get_user_item_matrix()
# Out:
# 2025-03-14 21:03:26,310 - INFO - Fetched user-item matrix: 1 users, 2 books
# book_id  2   24
# user_id
# 1         4   5
